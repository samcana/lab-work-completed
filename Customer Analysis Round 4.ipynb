# %%
import numpy as np
import pandas as pd

# %%
file1 = pd.read_csv('/Users/samkatterfield/Documents/IronHack/lab-work/march-24-pandas-data-cleaning/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
file1.shape
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower())
cols
# Out:
# ['customer',
#  'state',
#  'customer lifetime value',
#  'response',
#  'coverage',
#  'education',
#  'effective to date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location code',
#  'marital status',
#  'monthly premium auto',
#  'months since last claim',
#  'months since policy inception',
#  'number of open complaints',
#  'number of policies',
#  'policy type',
#  'policy',
#  'renew offer type',
#  'sales channel',
#  'total claim amount',
#  'vehicle class',
#  'vehicle size']

# %%
file1 = file1.rename(columns={'EmploymentStatus' : 'employment status'})

# %%
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date employment status Gender  Income  ...  \
# 0           2/24/11          Employed      F   56274  ...
# 1           1/31/11        Unemployed      F       0  ...
# 2           2/19/11          Employed      F   48767  ...
# 3           1/20/11        Unemployed      M       0  ...
# 4            2/3/11          Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower())
cols
# Out:
# ['customer',
#  'state',
#  'customer lifetime value',
#  'response',
#  'coverage',
#  'education',
#  'effective to date',
#  'employment status',
#  'gender',
#  'income',
#  'location code',
#  'marital status',
#  'monthly premium auto',
#  'months since last claim',
#  'months since policy inception',
#  'number of open complaints',
#  'number of policies',
#  'policy type',
#  'policy',
#  'renew offer type',
#  'sales channel',
#  'total claim amount',
#  'vehicle class',
#  'vehicle size']

# %%
file1.columns = cols

# %%
file1.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective to date employment status gender  income  ...  \
# 0           2/24/11          Employed      F   56274  ...
# 1           1/31/11        Unemployed      F       0  ...
# 2           2/19/11          Employed      F   48767  ...
# 3           1/20/11        Unemployed      M       0  ...
# 4            2/3/11          Employed      M   43836  ...
#
#   months since policy inception number of open complaints  number of policies  \
# ...

# %%
file1.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employment status                 object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim            int64
# months since policy inception      int64
# number of open complaints          int64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer lifetime value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective to date              9134 non-null   object
#  7   employment status              9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location code                  9134 non-null   object
#  11  marital status                 9134 non-null   object
# ...

# %%
missingdata=file1.isna()
missingdata.head()
# Out:
#    customer  state  customer lifetime value  response  coverage  education  \
# 0     False  False                    False     False     False      False
# 1     False  False                    False     False     False      False
# 2     False  False                    False     False     False      False
# 3     False  False                    False     False     False      False
# 4     False  False                    False     False     False      False
#
#    effective to date  employment status  gender  income  ...  \
# 0              False              False   False   False  ...
# 1              False              False   False   False  ...
# 2              False              False   False   False  ...
# 3              False              False   False   False  ...
# 4              False              False   False   False  ...
#
#    months since policy inception  number of open complaints  \
# 0                          False                      False
# ...

# %%
missingdata.sum()/len(file1)
# Out:
# customer                         0.0
# state                            0.0
# customer lifetime value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective to date                0.0
# employment status                0.0
# gender                           0.0
# income                           0.0
# location code                    0.0
# marital status                   0.0
# monthly premium auto             0.0
# months since last claim          0.0
# months since policy inception    0.0
# number of open complaints        0.0
# number of policies               0.0
# policy type                      0.0
# policy                           0.0
# renew offer type                 0.0
# sales channel                    0.0
# total claim amount               0.0
# vehicle class                    0.0
# vehicle size                     0.0
# dtype: float64

# %%
file1['effective to date'] = pd.to_datetime(file1['effective to date'], errors='coerce')

# %%
file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employment status                        object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                   int64
# months since policy inception             int64
# number of open complaints                 int64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %%
file1['Month'] = pd.DatetimeIndex(file1['effective to date']).month

# %%
file1.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective to date employment status gender  income  ...  \
# 0        2011-02-24          Employed      F   56274  ...
# 1        2011-01-31        Unemployed      F       0  ...
# 2        2011-02-19          Employed      F   48767  ...
# 3        2011-01-20        Unemployed      M       0  ...
# 4        2011-02-03          Employed      M   43836  ...
#
#   number of open complaints number of policies     policy type        policy  \
# ...

# %%
Q1 = file1[file1['Month'] < 3]

# %%
Q1.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective to date employment status gender  income  ...  \
# 0        2011-02-24          Employed      F   56274  ...
# 1        2011-01-31        Unemployed      F       0  ...
# 2        2011-02-19          Employed      F   48767  ...
# 3        2011-01-20        Unemployed      M       0  ...
# 4        2011-02-03          Employed      M   43836  ...
#
#   number of open complaints number of policies     policy type        policy  \
# ...

# %%
file1['Month'].value_counts()
# Out:
# 1    4898
# 2    4236
# Name: Month, dtype: int64

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer lifetime value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective to date              9134 non-null   datetime64[ns]
#  7   employment status              9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location code                  9134 non-null   object
#  11  marital status                 9134 non-null   object
# ...

# %%
file1.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months since last claim  months since policy inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
file1.describe(include=[np.object])
# Out:
# <ipython-input-63-c1a701ea4bc7>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   file1.describe(include=[np.object])
#        customer       state response coverage education employment status  \
# count      9134        9134     9134     9134      9134              9134
# unique     9134           5        2        3         5                 5
# top     VO61192  California       No    Basic  Bachelor          Employed
# freq          1        3150     7826     5568      2748              5698
#
#        gender location code marital status    policy type       policy  \
# count    9134          9134           9134           9134         9134
# unique      2             3              3              3            9
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import seaborn as sns

# %%
file1['response'].hist()
plt.show()

# %%
sns.countplot(x = "response", data = file1)
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
file1 = file1.rename(columns={ 'Total Claim Amount':'total_claim_amount', 'sales channel':'sales_channel'})

# %%
plt.figure(figsize = (12, 4))
sns.countplot(x = 'response', hue = 'sales_channel', data=file1)
plt.ylabel("Responses")
plt.title("Responses by Sales Channel")
plt.show()

# %%
file1.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'response', 'coverage',
#        'education', 'effective to date', 'employment status', 'gender',
#        'income', 'location code', 'marital status', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies', 'policy type',
#        'policy', 'renew offer type', 'sales_channel', 'total claim amount',
#        'vehicle class', 'vehicle size', 'Month'],
#       dtype='object')

# %%
plt.figure(figsize = (12, 4))
sns.countplot(x = 'response', hue = 'total claim amount', data=file1)
plt.ylabel("Responses")
plt.title("Responses by Sales Channel")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-ff697f575d26> in <module>
#       3 plt.ylabel("Responses")
#       4 plt.title("Responses by Sales Channel")
# ----> 5 plt.show()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
sns.boxplot(x = 'response',y='total claim amount', data=file1)
plt.show()

# %%
sns.displot(file1, x="total claim amount", bins=15, hue="response")

# %%
sns.displot(file1,y="income", bins=10, hue="response")

# %%
plt.figure(figsize = (20, 10))
sns.scatterplot(data=file1, x= "income", y="total claim amount", s=100, alpha = .1)
plt.title('Spaced out', loc='left')
# Out:
# Text(0.0, 1.0, 'Spaced out')

# %%
file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employment status                        object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                   int64
# months since policy inception             int64
# number of open complaints                 int64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %%
numerical=file1._get_numeric_data()
numerical.head()
# Out:
#    customer lifetime value  income  monthly premium auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months since last claim  months since policy inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number of open complaints  number of policies  total claim amount  Month
# 0                          0                   1          384.811147      2
# 1                          0                   8         1131.464935      1
# ...

# %%
categoricals = file1.select_dtypes(np.object)
# Out:
# <ipython-input-172-ead4421797dd>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categoricals = file1.select_dtypes(np.object)

# %%
categoricals.head()
# Out:
#   customer       state response  coverage education employment status gender  \
# 0  BU79786  Washington       No     Basic  Bachelor          Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor        Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor          Employed      F
# 3  WW63253  California       No     Basic  Bachelor        Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor          Employed      M
#
#   location code marital status     policy type        policy renew offer type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %%
sns.pairplot(numerical)

# %%
numerical.hist(bins=20, figsize=(15, 20), layout=(8, 2));

# %%
sns.pairplot(numerical.query('income > 0'))

# %%
numerical['income' > 0].hist(bins=40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-4cb3f93423d5> in <module>
# ----> 1 numerical['income' > 0].hist(bins=40)
#       2 plt.show()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
sns.jointplot(x=numerical['customer lifetime value'], y=numerical['monthly premium auto'])

# %%
sns.heatmap(numerical, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-193-42985b28f69b> in <module>
#       1 sns.heatmap(numerical, annot=True)
# ----> 2 plt.show()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
numerical.customer_lifetime_value.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')

# %%
plt.figure(figsize = (20, 10))
pp = sns.pairplot(data=numerical ,
                  y_vars=['total claim amount'],
                  x_vars=['income', 'monthly premium auto', 'months since last claim'])

pp

# %%
numerical.dtypes
# Out:
# customer lifetime value          float64
# income                             int64
# monthly premium auto               int64
# months since last claim            int64
# months since policy inception      int64
# number of open complaints          int64
# number of policies                 int64
# total claim amount               float64
# Month                              int64
# dtype: object

# %%
numerical.hist(x_vars=['total claim amount'],
                  y_vars=['income', 'monthly premium auto', 'months since last claim'], bins=20, figsize=(15, 20), layout=(8, 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-4caeeed57c00> in <module>
# ----> 1 numerical.hist(x_vars=['total claim amount'],
#       2                   y_vars=['income', 'monthly premium auto', 'months since last claim'], bins=20, figsize=(15, 20), layout=(8, 2))
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ...

# %%
sns.heatmap(numerical, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-42985b28f69b> in <module>
#       1 sns.heatmap(numerical, annot=True)
# ----> 2 plt.show()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~/opt/miniconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
numerical2 = numerical.drop(['number of policies', 'Month'] , axis = 1)

# %%
numerical2_matrix = numerical2.corr()
numerical2_matrix
# Out:
#                                customer lifetime value    income  \
# customer lifetime value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly premium auto                          0.396262 -0.016665
# months since last claim                       0.011517 -0.026715
# months since policy inception                 0.009418 -0.000875
# number of open complaints                    -0.036343  0.006408
# total claim amount                            0.226451 -0.355254
#
#                                monthly premium auto  months since last claim  \
# customer lifetime value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly premium auto                       1.000000                 0.005026
# months since last claim                    0.005026                 1.000000
# ...

# %%
sns.heatmap(numerical2_matrix, annot=True)
plt.show()

# %%
mask = np.zeros_like(numerical2_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(numerical2_matrix, annot=True)
plt.show()

# %%
sns.displot(numerical, x="customer_lifetime_value", bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-237-cf809d79bb4d> in <module>
# ----> 1 sns.displot(numerical2, x="customer_lifetime_value", bins=20)
#       2 plt.show()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2145 ):
#    2146
# -> 2147     p = _DistributionFacetPlotter(
#    2148         data=data,
#    2149         variables=_DistributionFacetPlotter.get_semantics(locals())
#
# ~/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     107     ):
#     108
# --> 109         super().__init__(data=data, variables=variables)
#     110
#     111     @property
#
# ...

# %%
fig, axes = plt.subplots(ncols=len(numerical.columns), figsize=(30,15))
for ax, col in zip(axes, numerical.columns):
  sns.distplot(numerical[col], ax=ax)
  plt.tight_layout() 
plt.show()
# Out:
# /Users/samkatterfield/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/samkatterfield/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig, axes = plt.subplots(4, 2,figsize=(15,15))
fig.suptitle('Numerical data for the dataframe')

for i,x in enumerate(numerical.columns):
    sns.distplot(numerical[x], ax=axes[int(i/2),i%2])
# Out:
# /Users/samkatterfield/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/samkatterfield/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.displot(numerical2, x="customer_lifetime_value", bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-254-cf809d79bb4d> in <module>
# ----> 1 sns.displot(numerical2, x="customer_lifetime_value", bins=20)
#       2 plt.show()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2145 ):
#    2146
# -> 2147     p = _DistributionFacetPlotter(
#    2148         data=data,
#    2149         variables=_DistributionFacetPlotter.get_semantics(locals())
#
# ~/opt/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     107     ):
#     108
# --> 109         super().__init__(data=data, variables=variables)
#     110
#     111     @property
#
# ...
