# %%
# #include at least one link to a website,
# news article or blog which discusses ethical issues with computer vision applications
# and add your personal thoughts and interpretation of this issue

# %%
import matplotlib

# %% [markdown]
# https://www.reuters.com/investigates/special-report/usa-riteaid-software/
# very long article...must admit I did not get to the end

# %% [markdown]
# *"The cameras matched facial images of customers entering a store to those of people Rite Aid previously observed engaging in **potential** criminal activity, causing an alert to be sent to security agents’ smartphones. Agents then reviewed the match for accuracy and could tell the customer to leave."*

# %% [markdown]
# 'Potential' sounds problematic here, as the corporation gets to define what behaviour it deems as anti-social. This behaviour may not even be illegal in the eyes of the law.
#
# Devil's advocate - the stores are private property, so Rite Aid can kind of withdraw your right to access for anything, within reason
#
# Usual questions: who has access to the data (especially images of people), who is it shared with,, how long is it kept for, do customers have the right to view it and request its deletion?
#
# Potential connections to the Chinese government and their policies on surveillance

# %% [markdown]
# *"Among the 75 stores Reuters visited, those in areas that were poorer or less white were much more likely to have the equipment, the news agency’s statistical analysis found.
#
# *Stores in more impoverished areas were nearly three times as likely as those in richer areas to have facial recognition cameras. Seventeen of 25 stores in poorer areas had the systems. In wealthier areas, it was 10 of 40. (Ten of the stores were in areas whose wealth status was not clear. Six of those stores had the equipment.)
#
# *In areas where people of color, including Black or Latino residents, made up the largest racial or ethnic group, Reuters found that stores were more than three times as likely to have the technology."""

# %% [markdown]
# In my limited experience, Rite Aid stores tend to be in lower-income neighbourhoods anyway, so the location of the specific stores in the article doesn't surprise me.
#
# The problems include the criminalisation of lower-income people and certain ethnic groups. It's the 21st century version of a security guard suspiciously following an african-american teenager around the shop
#
# It becomes a self-fulling prophecy. If the technology is rolled out in areas that have more ethnic minority customers...and the system shows up a couple of examples of anti-social behaviour by people of certain ethnicities, does that justify the system? The game is rigged!

# %% [markdown]
# Issues with the wrong person being identified by a system that is no way fool proof:
#
# *"According to a complaint Jackson-Stankunas filed with the California Department of Consumer Affairs a week after the incident, he was looking for air freshener in September 2016 when a manager ordered him to leave the store. The manager said he had received a security image of Jackson-Stankunas taken at another Rite Aid in 2013 from which he allegedly had stolen goods, according to the complaint.
#
# *When Jackson-Stankunas viewed the photo on the manager’s phone, he told Reuters, he saw nothing in common with the person except their race: Both are Black."

# %%
# generate an image from a caption you provide (choosing a theme from the drop down list),
# which you should display inside your notebook with the caption you provided 
# and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %% [markdown]
# **two people lying down at the beach **

# %%
# %matplotlib inline
from IPython.display import Image
Image('two-people-at-the-beach.png')

# %% [markdown]
# hmmmm 6 out of 10...the beach, sand, sea, sky are all good. I guess it has a whole base of static images to base that on?
#
# People seem to be an issue there...not sure what's happening. looks like a giant towel

# %%
#3) OPTIONAL (bonus+)

# %% [markdown]
# #the author did a quick sanity check himself with a browse:
#
# *To get a close look at this dataset, I used a fast image browser to check all images in the dogs and cats directories. Actually,
# *I simply used the Preview application on my mac to browse through the small preview icons
#
# he removed some cartoon images that popped up
